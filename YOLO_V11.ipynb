# %% [markdown]
# # **DETECTOR DE OBJETOS CON YOLO V11**

# %%
# INSTALACIÓN DE LIBRERÍAS NECESARIASA
#!pip install roboflow ultralytics
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# DESCARGA DE DATASET PERSONALIZADO DESDE ROBOFLOW
#!pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="YP6UX0p6bmRnwAjcSbfY")
project = rf.workspace("nella-hyakz").project("custom_object_detector_yolo11_v2-rotnm")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# CARGA DEL MODELO BASE YOLO V11
from ultralytics import YOLO
model = YOLO("yolo11s.pt")

# %%
# ENTRENAMIENTO DEL MODELO PERSONALIZADO
data_path = "C:/Users/Nella/Desktop/YOLO_V11/custom_object_detector_yolo11_v2-1/data.yaml"
results= model.train (data=data_path,
epochs=15,
imgsz=640)
# Out:
# Ultralytics 8.3.227  Python-3.12.7 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# ...

# %% [markdown]
# # Predicciones

# %%
# CARGAR EL MODELO YA ENTRENADO
custom_model = YOLO("C:/Users/Nella/Desktop/YOLO_V11/runs/detect/train/weights/best.pt")

# %%
# REALIZAR PREDICCIONES SOBRE ALGUNAS IMÁGENES
res = custom_model("C:/Users/Nella/Desktop/YOLO_V11/custom_object_detector_yolo11_v2-1/test/images")
# Out:
# image 1/2 C:\Users\Nella\Desktop\YOLO_V11\custom_object_detector_yolo11_v2-1\test\images\15_jpg.rf.6466b884f83f211fcda1ac71dfa1ae03.jpg: 384x640 16 manzanass, 48.0ms
# image 2/2 C:\Users\Nella\Desktop\YOLO_V11\custom_object_detector_yolo11_v2-1\test\images\5_jpg.rf.7c994e01cd72611e87d30ecc725a9730.jpg: 384x640 12 manzanass, 22.9ms
# Speed: 4.0ms preprocess, 35.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)

# %%
# VISUALIZAR LOS RESULTADOS DE LAS DETECCIONES
res[0].show()

# %%
# VISUALIZAR LOS RESULTADOS DE LAS DETECCIONES
res[1].show()
